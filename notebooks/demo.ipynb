# %%
# Add relevant Jupyter notebook extensions 
import uuv_mission

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Library/Frameworks/Python.framework/Versions/3.10/lib/python310.zip', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload', '', '/Users/alrikcheung/Library/CloudStorage/OneDrive-Nexus365/B1 Practical/b1-coding-practical-mt24/.venv/lib/python3.10/site-packages']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules and run a short example
from uuv_mission.dynamic import Submarine, ClosedLoop, Control, Mission, Trajectory

sub = Submarine()
controller = Control()
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("../data/mission.csv")

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
